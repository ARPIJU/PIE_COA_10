# %% [markdown]
# <a href="https://colab.research.google.com/github/ARPIJU/PIE_COA_10/blob/main/notebooks/test2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ARPIJU/PIE_COA_10.git
# %cd PIE_COA_10
# !ls
# Out:
# Cloning into 'PIE_COA_10'...
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 39 (delta 8), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (39/39), 479.69 KiB | 4.52 MiB/s, done.
# Resolving deltas: 100% (8/8), done.
# /content/PIE_COA_10/PIE_COA_10
# Boeing_Perf_Data.txt  main.py	notebooks  Untitled0.ipynb
# classes		      notebook	README.md

# %%
# !python3 main.py
