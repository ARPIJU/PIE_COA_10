# %% [markdown]
# <a href="https://colab.research.google.com/github/ARPIJU/PIE_COA_10/blob/main/notebooks/start_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Monter Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Aller directement dans ton projet
# %cd /content/drive/MyDrive/PIE_COA_10

# Vérifier l'arborescence
# !ls -R
