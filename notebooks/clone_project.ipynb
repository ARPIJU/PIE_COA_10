# %% [markdown]
# <a href="https://colab.research.google.com/github/ARPIJU/PIE_COA_10/blob/main/notebooks/clone_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Monter Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Créer le dossier projet dans Drive (si pas déjà présent)
# !mkdir -p /content/drive/MyDrive/PIE_COA_10

# Cloner le dépôt GitHub dans Drive
# !git clone https://github.com/ARPIJU/PIE_COA_10.git /content/drive/MyDrive/PIE_COA_10

# Vérifier l'arborescence
# %cd /content/drive/MyDrive/PIE_COA_10
# !ls -R
