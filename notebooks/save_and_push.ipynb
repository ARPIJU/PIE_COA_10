# %% [markdown]
# <a href="https://colab.research.google.com/github/ARPIJU/PIE_COA_10/blob/main/notebooks/save_and_push.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/drive/MyDrive/PIE_COA_10
# !git add .
# !git commit -m "Sauvegarde automatique depuis Colab"
# !git push origin main
